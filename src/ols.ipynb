# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from pathlib import Path

# %% [markdown]
# ### 1. Response Selection and Preprocessing
#
# Select **one** of the following response variables:
# - Willingness to pay (in euros)
# - Number of edits to improve the image
#
# Prepare the dataset by:
# - Encoding categorical variables (e.g. creating dummy variables when needed)
# - Adding an intercept term
#
# I chose willingness to pay in euros

# %%
# Build path to dataset

dataset_path = Path().resolve().parent / "dataset" / "data.csv"

df = pd.read_csv(dataset_path)

# %%
# Initial checks

print(f'shape = {df.shape}')
print()
print(df.info())
print()
#print(df.describe(include="all"))
# Out:
# shape = (96, 11)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 11 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   ID                                                                                            96 non-null     int64
#  1   IMAGE                                                                                         96 non-null     int64
#  2   How scary is this image?                                                                      96 non-null     int64
#  3   How likely are you to see something like this in  a dream?                                    96 non-null     object
#  4   What is the dominant emotion of the image?                                                    93 non-null     object
#  5   How realistic does this image look?                                                           96 non-null     int64
#  6   How likely is this image AI-generated?                                                        96 non-null     int64
#  7   How much would you pay for this as a painting (in euros)?                                     96 non-null     object
#  8   If you were asked to improve this image to make it “perfect”, how many edits would you make?  91 non-null     object
#  9   Write a short story inspired by this image without naming any objects in it.                  71 non-null     object
#  10  Does anything feel visually wrong/inconsistent in this image?                                 96 non-null     object
# dtypes: int64(5), object(6)
# memory usage: 8.4+ KB
# None

# %%
# Drop some columns

cols_to_drop = [
    "ID",
    "Write a short story inspired by this image without naming any objects in it.",
    "If you were asked to improve this image to make it “perfect”, how many edits would you make?"
]

df = df.drop(columns = cols_to_drop)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 8 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   IMAGE                                                          96 non-null     int64
#  1   How scary is this image?                                       96 non-null     int64
#  2   How likely are you to see something like this in  a dream?     96 non-null     object
#  3   What is the dominant emotion of the image?                     93 non-null     object
#  4   How realistic does this image look?                            96 non-null     int64
#  5   How likely is this image AI-generated?                         96 non-null     int64
#  6   How much would you pay for this as a painting (in euros)?      96 non-null     object
#  7   Does anything feel visually wrong/inconsistent in this image?  96 non-null     object
# dtypes: int64(4), object(4)
# memory usage: 6.1+ KB

# %%
# check the column willingness to pay

df_response = df['How much would you pay for this as a painting (in euros)?']

unique_values = set(df_response.dropna())
print(unique_values)
# Out:
# {'100', '18', '25', '1', '50', '0€', '6', '150', '2', '8', '15', '-10', '€5', '0', '10', 'O', '5', '3', '20', 'Zero', '10€'}

# %%
# Drop rows containing invalid values

def clean_price(x):
    if pd.isna(x):
        return np.nan

    x = str(x).strip().lower()

    # textual zeros
    if x in ["zero", "o"]:
        return 0.0

    # remove euro symbol
    x = x.replace("€", "")

    # try numeric conversion
    try:
        value = float(x)
    except ValueError:
        return np.nan

    # remove invalid values
    if value < 0:
        return np.nan

    return value

response_col = "How much would you pay for this as a painting (in euros)?"

df[response_col] = df[response_col].apply(clean_price)
df = df.dropna(subset=[response_col])

set(df[response_col].unique())
# Out:
# {np.float64(0.0),
#  np.float64(1.0),
#  np.float64(2.0),
#  np.float64(3.0),
#  np.float64(5.0),
#  np.float64(6.0),
#  np.float64(8.0),
#  np.float64(10.0),
#  np.float64(15.0),
#  np.float64(18.0),
#  np.float64(20.0),
#  np.float64(25.0),
#  np.float64(50.0),
#  np.float64(100.0),
#  np.float64(150.0)}

# %%
# Encoding categorical variables

dream_col = "How likely are you to see something like this in  a dream?"
emotion_col = "What is the dominant emotion of the image?"

df = pd.get_dummies(
    df,
    columns = [dream_col],
    drop_first=True
)

df = pd.get_dummies(
    df,
    columns=[emotion_col],
    drop_first=True
)

# %%
wrong_col = "Does anything feel visually wrong/inconsistent in this image?"

df["visually_wrong"] = (
    ~df[wrong_col].str.lower().str.contains("no")
).astype(int)

bool_cols = df.select_dtypes(include="bool").columns
df[bool_cols] = df[bool_cols].astype(int)

df = df.drop(columns=[wrong_col])

print(df.head())
# Out:
#    IMAGE  How scary is this image?  How realistic does this image look?  \
# 0      1                         6                                    1
# 1      1                         3                                    3
# 2      1                         8                                    2
# 3      1                         1                                    1
# 4      1                         1                                    1
#
#    How likely is this image AI-generated?  \
# 0                                       8
# 1                                      10
# 2                                      10
# 3                                       2
# 4                                       7
#
#    How much would you pay for this as a painting (in euros)?  \
# 0                                                2.0
# 1                                                0.0
# 2                                                8.0
# 3                                                0.0
# 4                                                0.0
#
#    How likely are you to see something like this in  a dream?_Neutral  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    How likely are you to see something like this in  a dream?_Unlikely  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  1
#
#    How likely are you to see something like this in  a dream?_Very unlikely  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
# 3                                                  1
# 4                                                  0
#
#    What is the dominant emotion of the image?_Anger, confusion  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    What is the dominant emotion of the image?_Anxiety  ...  \
# 0                                                  0   ...
# 1                                                  0   ...
# 2                                                  0   ...
# 3                                                  0   ...
# 4                                                  0   ...
#
#    What is the dominant emotion of the image?_Sadness, Fear, Anger  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    What is the dominant emotion of the image?_Stupidity  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    What is the dominant emotion of the image?_Surprise  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    What is the dominant emotion of the image?_Tenderness  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    What is the dominant emotion of the image?_Wonder   \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    What is the dominant emotion of the image?_adventurous  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    What is the dominant emotion of the image?_feeling of cuteness  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    What is the dominant emotion of the image?_neutral  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    What is the dominant emotion of the image?_no emotion / neutral  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    visually_wrong
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
#
# [5 rows x 44 columns]

# %%
# Intercept for the design matrix
response_col = "How much would you pay for this as a painting (in euros)?"

X = df.drop(columns=[response_col])
y = df[response_col].values

X.insert(0, "intercept", 1.0)

bool_cols = X.select_dtypes(include='bool').columns
X[bool_cols] = X[bool_cols].astype(int)
 

X
# Out:
#     intercept  IMAGE  How scary is this image?  \
# 0         1.0      1                         6
# 1         1.0      1                         3
# 2         1.0      1                         8
# 3         1.0      1                         1
# 4         1.0      1                         1
# ..        ...    ...                       ...
# 91        1.0      3                         1
# 92        1.0      3                         1
# 93        1.0      3                         2
# 94        1.0      3                         3
# 95        1.0      3                         2
#
#     How realistic does this image look?  \
# 0                                     1
# 1                                     3
# 2                                     2
# 3                                     1
# 4                                     1
# ..                                  ...
# 91                                    3
# 92                                    2
# 93                                    5
# 94                                    3
# 95                                    6
#
#     How likely is this image AI-generated?  \
# 0                                        8
# 1                                       10
# 2                                       10
# 3                                        2
# 4                                        7
# ..                                     ...
# 91                                       5
# 92                                       9
# 93                                       4
# 94                                      10
# 95                                       8
#
#     How likely are you to see something like this in  a dream?_Neutral  \
# 0                                                   1
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 91                                                  1
# 92                                                  0
# 93                                                  0
# 94                                                  0
# 95                                                  0
#
#     How likely are you to see something like this in  a dream?_Unlikely  \
# 0                                                   0
# 1                                                   0
# 2                                                   1
# 3                                                   0
# 4                                                   1
# ..                                                ...
# 91                                                  0
# 92                                                  0
# 93                                                  0
# 94                                                  0
# 95                                                  0
#
#     How likely are you to see something like this in  a dream?_Very unlikely  \
# 0                                                   0
# 1                                                   1
# 2                                                   0
# 3                                                   1
# 4                                                   0
# ..                                                ...
# 91                                                  0
# 92                                                  1
# 93                                                  1
# 94                                                  0
# 95                                                  0
#
#     What is the dominant emotion of the image?_Anger, confusion  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 91                                                  0
# 92                                                  0
# 93                                                  0
# 94                                                  0
# 95                                                  0
#
#     What is the dominant emotion of the image?_Anxiety  ...  \
# 0                                                   0   ...
# 1                                                   0   ...
# 2                                                   0   ...
# 3                                                   0   ...
# 4                                                   0   ...
# ..                                                ...   ...
# 91                                                  0   ...
# 92                                                  0   ...
# 93                                                  0   ...
# 94                                                  0   ...
# 95                                                  0   ...
#
#     What is the dominant emotion of the image?_Sadness, Fear, Anger  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 91                                                  0
# 92                                                  0
# 93                                                  0
# 94                                                  0
# 95                                                  0
#
#     What is the dominant emotion of the image?_Stupidity  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 91                                                  0
# 92                                                  0
# 93                                                  0
# 94                                                  0
# 95                                                  0
#
#     What is the dominant emotion of the image?_Surprise  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 91                                                  0
# 92                                                  0
# 93                                                  0
# 94                                                  0
# 95                                                  0
#
#     What is the dominant emotion of the image?_Tenderness  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 91                                                  0
# 92                                                  0
# 93                                                  0
# 94                                                  0
# 95                                                  0
#
#     What is the dominant emotion of the image?_Wonder   \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 91                                                  0
# 92                                                  0
# 93                                                  0
# 94                                                  0
# 95                                                  0
#
#     What is the dominant emotion of the image?_adventurous  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 91                                                  0
# 92                                                  0
# 93                                                  0
# 94                                                  0
# 95                                                  0
#
#     What is the dominant emotion of the image?_feeling of cuteness  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 91                                                  0
# 92                                                  0
# 93                                                  0
# 94                                                  0
# 95                                                  0
#
#     What is the dominant emotion of the image?_neutral  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 91                                                  0
# 92                                                  0
# 93                                                  0
# 94                                                  0
# 95                                                  0
#
#     What is the dominant emotion of the image?_no emotion / neutral  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 91                                                  0
# 92                                                  0
# 93                                                  0
# 94                                                  0
# 95                                                  0
#
#     visually_wrong
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ..             ...
# 91               1
# 92               1
# 93               0
# 94               1
# 95               1
#
# [95 rows x 44 columns]

# %% [markdown]
# ## Linear Regression Implementation

# %%
def fit_ols(X, y):

    XTX = X.T @ X
    XTy = X.T @ y

    beta_hat = np.linalg.pinv(XTX) @ XTy

    return beta_hat

def predict_ols(X, beta):

    return X @ beta

def mse(y_true, y_pred):

    return np.mean((y_true - y_pred) ** 2)

def r2_score(y_true, y_pred):

    ss_res = np.sum((y_true - y_pred) ** 2)
    ss_tot = np.sum((y_true - np.mean(y_true)) ** 2)
    return 1 - ss_res / ss_tot

# %%
X_np = X.to_numpy(dtype=float)   # converts all columns to floats
y_np = y.astype(float) 
beta_hat = fit_ols(X.values, y)
pred = predict_ols(X, beta_hat)
y_hat = predict_ols(X.values, beta_hat)

beta_hat = fit_ols(X_np, y_np)
y_hat = predict_ols(X_np, beta_hat)

print("Coefficients:", beta_hat)
print(f'prediction: {pred}')
print("MSE:", mse(y_np, y_hat))
print("R^2:", r2_score(y_np, y_hat))
# Out:
# Coefficients: [-20.01456142   1.41641581   0.97316966   5.62045926  -0.06787859
#    2.34253703  13.8701032   -1.42195214  11.40011635  -6.81144798
#    4.03182083 -31.09717314 -35.70546891 -17.18843643  11.0607234
#    7.74264071  -4.63782622   4.58792872 -23.74070436   1.04018242
#   -1.38205494  -5.64774776   7.59416721   2.53272565 -12.06589057
#   15.92496621   3.11855725  10.78920903  -0.17213119 -10.77792361
#  -20.01016172   2.4145761   -7.01508375  -8.32458588   7.3226007
#    5.57602131   9.71218618 -24.63102867   7.76584685   7.14533259
#    1.65570041  -8.1920107   -7.56306863   2.70513838]
# prediction: 0      1.397799
# 1      0.405087
# 2      8.000000
# 3     -3.114447
# 4     11.689742
#         ...
# 91    10.809337
# 92     1.152874
# 93    16.621676
# 94    10.073746
# 95    10.000000
# Length: 95, dtype: float64
# MSE: 299.4499611934456
# R^2: 0.37212152039809054

# %% [markdown]
# ## Comparison with Standard Libraries:

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Create the model
lr = LinearRegression(fit_intercept=False)  # intercept already in X

# Fit the model
lr.fit(X.values, y)  

# Predictions
y_pred_skl = lr.predict(X.values)

# Coefficients
beta_skl = lr.coef_

# MSE and R^2
mse_skl = mean_squared_error(y, y_pred_skl)
r2_skl = r2_score(y, y_pred_skl)

print("scikit-learn Coefficients:", beta_skl)
print("prediction", y_pred_skl)
print("MSE:", mse_skl)
print("R^2:", r2_skl)
# Out:
# scikit-learn Coefficients: [-20.01456142   1.41641581   0.97316966   5.62045926  -0.06787859
#    2.34253703  13.8701032   -1.42195214  11.40011635  -6.81144798
#    4.03182083 -31.09717314 -35.70546891 -17.18843643  11.0607234
#    7.74264071  -4.63782622   4.58792872 -23.74070436   1.04018242
#   -1.38205494  -5.64774776   7.59416721   2.53272565 -12.06589057
#   15.92496621   3.11855725  10.78920903  -0.17213119 -10.77792361
#  -20.01016172   2.4145761   -7.01508375  -8.32458588   7.3226007
#    5.57602131   9.71218618 -24.63102867   7.76584685   7.14533259
#    1.65570041  -8.1920107   -7.56306863   2.70513838]
# prediction [ 1.39779915e+00  4.05086565e-01  8.00000000e+00 -3.11444691e+00
#   1.16897420e+01  1.00000000e+01  3.55093231e+00  5.00000000e+00
#  -3.18232550e+00  3.10862447e-15 -6.35047570e-14 -8.14121441e+00
#  -3.86357613e-14  1.52007361e+01 -6.39512586e+00  4.23431720e+01
#  -2.69702229e+00 -4.43246149e-01 -1.99840144e-14 -8.68585687e+00
#   5.70090740e+00 -8.21565038e-14 -5.19584376e-14  5.00000000e+00
#   2.13825320e+01 -5.90638649e-14 -8.48060737e+00 -3.26441339e+00
#   5.06874443e+00 -8.91766166e+00  5.94603151e+00 -3.41948692e-14
#   2.61864201e+01 -4.82465033e+00  1.87793624e+01 -1.69803110e+00
#  -3.34709276e+00  1.00000000e+01  3.51446051e+01 -4.48530102e-14
#   3.05905057e+00 -1.45536482e+01  1.41642119e+01  1.04902076e+00
#   2.94562673e+01  5.00000000e+00  3.00000000e+00  4.07013739e+01
#   2.24219310e+01 -3.41948692e-14 -5.54460817e+00 -1.62687985e+00
#   1.07884954e+01  1.27696509e+01 -3.31420447e-01 -5.60309637e-01
#   3.47717763e+01 -1.33226763e-15  5.83206754e+00  1.00000000e+00
#  -4.04121181e-14  1.36609086e+01  2.49739726e+01  1.33909139e+00
#   7.40737799e+00  1.06983360e+01 -8.31481829e+00 -2.62012634e-14
#  -4.66293670e-14  4.47508614e+01  2.45536482e+01 -2.70894418e-14
#  -4.16611190e-14  1.49874227e+01  2.94812967e+01  4.04877200e+00
#  -4.53546390e+00  4.75304251e+01  3.70439072e+01  3.64973304e+01
#   4.43246149e-01  7.88227582e-01 -6.41730963e+00  1.98251020e+01
#   2.12010870e+01  1.23937925e+01 -4.26394954e+00 -7.10542736e-14
#   3.18958251e+00  2.05816503e+00  1.08093368e+01  1.15287395e+00
#   1.66216760e+01  1.00737461e+01  1.00000000e+01]
# MSE: 299.4499611934456
# R^2: 0.37212152039809054

# %% [markdown]
# #### The coefficients, MSE, and R² from our scratch implementation of OLS match exactly those obtained from scikit-learn, confirming the correctness of the matrix-based approach. Small numerical differences may occur in larger or ill-conditioned datasets due to different numerical methods used for solving the linear system.

# %% [markdown]
# ## Interaction Effects and Feature Engineering:
#
# ### I picked : How scary is this image? and How realistic does this image look? → numeric, could change the effect of “scary”

# %%
# Assuming X contains your numeric predictors
X_interact = X.copy()

# Interaction term
X_interact['scary_x_realistic'] = X_interact['How scary is this image?'] * X_interact['How realistic does this image look?']

# Convert booleans to int again if needed
bool_cols = X_interact.select_dtypes(include='bool').columns
X_interact[bool_cols] = X_interact[bool_cols].astype(int)

# Convert to NumPy
X_int_np = X_interact.to_numpy(dtype=float)

# Fit
beta_int = fit_ols(X_int_np, y_np)
y_hat_int = predict_ols(X_int_np, beta_int)

# Evaluate
mse_int = mse(y_np, y_hat_int)
r2_int = r2_score(y_np, y_hat_int)

print("MSE with interaction:", mse_int)
print("R² with interaction:", r2_int)

print("MSE without interaction:", mse(y_np, y_hat))
print("R² without interaction:", r2_score(y_np, y_hat))
